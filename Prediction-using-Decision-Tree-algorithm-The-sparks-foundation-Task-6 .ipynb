# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Shatla/Prediction-using-Decision-Tree-algorithm-The-sparks-foundation-Task-6-/blob/main/Prediction-using-Decision-Tree-algorithm-The-sparks-foundation-Task-6%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Author: Ahmed Mohamed Abdelaziz

# %% [markdown]
# ####task 6: Prediction using decision tree algorithm (iris dataset)

# %% [markdown]
# ##importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Reading the dataset

# %%
data = pd.read_csv('/content/drive/MyDrive/sparks/Iris.csv')
X,y = data.iloc[:,:-1],data.iloc[:,-1]

# %% [markdown]
# ##Drop ID column

# %%
X=X.drop(['Id'],axis=1)

# %% [markdown]
# ##Splitting dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# ##Training the dicision tree model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier().fit(X_train,y_train)

# %% [markdown]
# ##Evaluating the model

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
print("The Accuracy Score = ")
print(accuracy_score(y_test,y_pred))
# Out:
# The Accuracy Score =
# 0.9666666666666667

# %% [markdown]
# ##Visualization

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,13))
plot_tree(model, feature_names = X.columns)
# Out:
# [Text(0.36363636363636365, 0.9285714285714286, 'PetalWidthCm <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.2727272727272727, 0.7857142857142857, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.45454545454545453, 0.7857142857142857, 'PetalLengthCm <= 4.85\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.18181818181818182, 0.6428571428571429, 'PetalWidthCm <= 1.65\ngini = 0.095\nsamples = 40\nvalue = [0, 38, 2]'),
#  Text(0.09090909090909091, 0.5, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.2727272727272727, 0.5, 'SepalWidthCm <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.18181818181818182, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.36363636363636365, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7272727272727273, 0.6428571428571429, 'PetalWidthCm <= 1.7\ngini = 0.097\nsamples = 39\nvalue = [0, 2, 37]'),
#  Text(0.6363636363636364, 0.5, 'PetalLengthCm <= 4.95\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.5454545454545454, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7272727272727273, 0.35714285714285715, 'PetalWidthCm <= 1.55\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.6363636363636364, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8181818181818182, 0.21428571428571427, 'SepalLengthCm <= 6.6\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.7272727272727273, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9090909090909091, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8181818181818182, 0.5, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]')]
