# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Shatla/Prediction-using-Decision-Tree-algorithm-The-sparks-foundation-Task-6-/blob/main/Prediction-using-Decision-Tree-algorithm-The-sparks-foundation-Task-6%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Author: Ahmed Mohamed Abdelaziz

# %% [markdown]
# ####task 6: Prediction using decision tree algorithm (iris dataset)

# %% [markdown]
# ##importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Reading the dataset

# %%
data = pd.read_csv('/content/drive/MyDrive/sparks/Iris.csv')
X,y = data.iloc[:,:-1],data.iloc[:,-1]

# %% [markdown]
# ##Drop ID column

# %%
X=X.drop(['Id'],axis=1)

# %% [markdown]
# ##Splitting dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# ##Training the dicision tree model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier().fit(X_train,y_train)

# %% [markdown]
# ##Evaluating the model

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
print("The Accuracy Score = ")
print(accuracy_score(y_test,y_pred))
# Out:
# The Accuracy Score =
# 0.9666666666666667

# %% [markdown]
# ##Visualization

# %%
from sklearn.tree import plot_tree, export_text
plt.figure(figsize=(20,13))
plot_tree(model, feature_names = X.columns)
# Out:
# [Text(0.4, 0.9166666666666666, 'PetalWidthCm <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.5, 0.75, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.2, 0.5833333333333334, 'PetalLengthCm <= 4.95\ngini = 0.169\nsamples = 43\nvalue = [0, 39, 4]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.3, 0.4166666666666667, 'PetalWidthCm <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.25, 'PetalLengthCm <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.3, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8, 0.5833333333333334, 'PetalLengthCm <= 4.85\ngini = 0.054\nsamples = 36\nvalue = [0, 1, 35]'),
# ...
